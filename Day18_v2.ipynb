# %%
with open("Inputs/Day18.txt", "r") as input:
    input = input.read()

# %%
cubes = set()
for line in input.split("\n"):
    coords = list(map(int, line.split(",")))
    cubes.add(tuple(coords))

# %%
min_x = 1e6
max_x = -10
min_y = 1e6
max_y = -10
min_z = 1e6
max_z = -10

for cube in cubes:
    if cube[0] < min_x:
        min_x = cube[0]
    if cube[1] < min_y:
        min_y = cube[1]
    if cube[2] < min_z:
        min_z = cube[2]
    if cube[0] > max_x:
        max_x = cube[0]
    if cube[1] > max_y:
        max_y = cube[1]
    if cube[2] > max_z:
        max_z = cube[2]

# %%
def hasReachedEdge(cube):
   return cube[0] < min_x or cube[0] > max_x or cube[1] < min_y or cube[1] > max_y or cube[2] < min_z or cube[2] > max_z

# %%
def isCubeAccessible(cube, cubes, visited):
    increment_x_cube = list(cube)
    increment_x_cube[0] += 1
    increment_x_cube = tuple(increment_x_cube)
    if not hasReachedEdge(increment_x_cube):
        if increment_x_cube not in visited:
            if increment_x_cube not in cubes:
                visited.add(increment_x_cube)
                if isCubeAccessible(increment_x_cube, cubes, visited):
                    return True
    else:
        return True

    increment_y_cube = list(cube)
    increment_y_cube[1] += 1
    increment_y_cube = tuple(increment_y_cube)
    if not hasReachedEdge(increment_y_cube):
        if increment_y_cube not in visited:
            if increment_y_cube not in cubes:
                visited.add(increment_y_cube)
                if isCubeAccessible(increment_y_cube, cubes, visited):
                    return True
    else:
        return True
    
    increment_z_cube = list(cube)
    increment_z_cube[2] += 1
    increment_z_cube = tuple(increment_z_cube)
    if not hasReachedEdge(increment_z_cube):
        if increment_z_cube not in visited:
            if increment_z_cube not in cubes:
                visited.add(increment_z_cube)
                if isCubeAccessible(increment_z_cube, cubes, visited):
                    return True
    else:
        return True

    decrement_x_cube = list(cube)
    decrement_x_cube[0] -= 1
    decrement_x_cube = tuple(decrement_x_cube)
    if not hasReachedEdge(decrement_x_cube):
        if decrement_x_cube not in visited:
            if decrement_x_cube not in cubes:
                visited.add(decrement_x_cube)
                if isCubeAccessible(decrement_x_cube, cubes, visited):
                    return True
    else:
        return True

    decrement_y_cube = list(cube)
    decrement_y_cube[1] -= 1
    decrement_y_cube = tuple(decrement_y_cube)
    if not hasReachedEdge(decrement_y_cube):
        if decrement_y_cube not in visited:
            if decrement_y_cube not in cubes:
                visited.add(decrement_y_cube)
                if isCubeAccessible(decrement_y_cube, cubes, visited):
                    return True
    else:
        return True
    
    decrement_z_cube = list(cube)
    decrement_z_cube[2] -= 1
    decrement_z_cube = tuple(decrement_z_cube)
    if not hasReachedEdge(decrement_z_cube):
        if decrement_z_cube not in visited:
            if decrement_z_cube not in cubes:
                visited.add(decrement_z_cube)
                if isCubeAccessible(decrement_z_cube, cubes, visited):
                    return True
    else:
        return True
    return False

# %%
num_accessible_sides = 0
for cube in cubes:
    increment_x_cube = list(cube)
    increment_x_cube[0] += 1
    increment_x_cube = tuple(increment_x_cube)
    if increment_x_cube not in cubes and isCubeAccessible(increment_x_cube, cubes, set()):
        num_accessible_sides += 1

    increment_y_cube = list(cube)
    increment_y_cube[1] += 1
    increment_y_cube = tuple(increment_y_cube)
    if increment_y_cube not in cubes and isCubeAccessible(increment_y_cube, cubes, set()):
        num_accessible_sides += 1

    increment_z_cube = list(cube)
    increment_z_cube[2] += 1
    increment_z_cube = tuple(increment_z_cube)
    if increment_z_cube not in cubes and isCubeAccessible(increment_z_cube, cubes, set()):
        num_accessible_sides += 1

    decrement_x_cube = list(cube)
    decrement_x_cube[0] -= 1
    decrement_x_cube = tuple(decrement_x_cube)
    if decrement_x_cube not in cubes and isCubeAccessible(decrement_x_cube, cubes, set()):
        num_accessible_sides += 1

    decrement_y_cube = list(cube)
    decrement_y_cube[1] -= 1
    decrement_y_cube = tuple(decrement_y_cube)
    if decrement_y_cube not in cubes and isCubeAccessible(decrement_y_cube, cubes, set()):
        num_accessible_sides += 1

    decrement_z_cube = list(cube)
    decrement_z_cube[2] -= 1
    decrement_z_cube = tuple(decrement_z_cube)
    if decrement_z_cube not in cubes and isCubeAccessible(decrement_z_cube, cubes, set()):
        num_accessible_sides += 1
    
    print(num_accessible_sides)

num_accessible_sides
# Out:
# 0
# 0
# 0
# 0
# 3
# 4
# 7
# 7
# 7
# 7
# 10
# 13
# 13
# 15
# 15
# 15
# 16
# 16
# 16
# 18
# 19
# 19
# 20
# 25
# 25
# 25
# 30
# 30
# 30
# 31
# 31
# 31
# 34
# 34
# 37
# 38
# 38
# 39
# 41
# 41
# 41
# 41
# 41
# 41
# 41
# 43
# 43
# 43
# 47
# 49
# 49
# 53
# 55
# 55
# 55
# 56
# 57
# 57
# 57
# 57
# 61
# 61
# 61
# 66
# 66
# 67
# 68
# 68
# 70
# 70
# 70
# 72
# 72
# 74
# 74
# 78
# 78
# 78
# 78
# 78
# 78
# 80
# 80
# 80
# 83
# 87
# 90
# 91
# 91
# 91
# 95
# 95
# 95
# 98
# 98
# 100
# 100
# 100
# 100
# 100
# 103
# 103
# 103
# 103
# 104
# 104
# 104
# 104
# 104
# 104
# 104
# 105
# 105
# 109
# 109
# 109
# 111
# 111
# 112
# 112
# 113
# 113
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 115
# 118
# 118
# 121
# 121
# 121
# 125
# 125
# 129
# 129
# 129
# 131
# 131
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 132
# 133
# 133
# 133
# 136
# 136
# 136
# 139
# 140
# 144
# 144
# 148
# 148
# 148
# 148
# 148
# 148
# 150
# 152
# 152
# 153
# 153
# 153
# 153
# 157
# 157
# 160
# 161
# 162
# 163
# 164
# 165
# ...
